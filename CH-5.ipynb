# %% [markdown]
# # MNN
# 1. TP = True Positive
# 2. TN = True Negative
# 3. FP = FALSE POSITIVE
# 4. FN = FALSE Negative
# if prediction is positive and actual was true so TP.
#
# <!-- table -->
#           predicted
#             |  no     |   yes
# ---------------------------
# actual | no | tn      |   fp
#        | yes| fn      |   tp
# <!--accuracy -->
# =(tp+tn)/total
#
# <!--error rate  -->
# =(fp+fn)/total ==1- accuracy
#
# <!--sensitivity = positive direction ma model nu sachu padvano rate -->
# =(tp)/tp+fn
#
# <!-- specificity = positive direction ma model nu khotu padvano rate-->
# =(tn)/tn+fp

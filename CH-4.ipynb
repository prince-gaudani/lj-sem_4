# %%
import pandas as pd
df=pd.read_csv('Book1.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
y=df['package']
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
x=df[['cgpa']]
x.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
x_test.shape
# Out:
# (40, 1)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (40,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# Out:
# array([0.55795197])

# %%
c=lr.intercept_
c
# Out:
# np.float64(-0.8961119222429126)

# %%
#if x=cgpa=5.65
y1=(m*5.65+c)
y1
# Out:
# array([2.25631673])

# %%
y2=lr.predict([[5.65]])
y2
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.25631673])

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
from sklearn.metrics import mean_squared_error
print('mse=',mean_squared_error(y_test,y_pred))
# Out:
# mse= 0.12129235313495527

# %%
df=pd.read_csv('student_scores.csv')
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
x=df[['Hours']]
y=df['Scores']

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
df=pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['age']=2026-df["Year"]
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  age
# 0        Dealer       Manual      0   12
# 1        Dealer       Manual      0   13
# 2        Dealer       Manual      0    9
# 3        Dealer       Manual      0   15
# 4        Dealer       Manual      0   12
# ..          ...          ...    ...  ...
# 296      Dealer       Manual      0   10
# 297      Dealer       Manual      0   11
# 298      Dealer       Manual      0   17
# 299      Dealer       Manual      0    9
# 300      Dealer       Manual      0   10
#
# [301 rows x 10 columns]

# %%
df.drop(columns="Year",inplace=True)

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  age
# 0         Manual      0   12
# 1         Manual      0   13
# 2         Manual      0    9
# 3         Manual      0   15
# 4         Manual      0   12
# ..           ...    ...  ...
# 296       Manual      0   10
# 297       Manual      0   11
# 298       Manual      0   17
# 299       Manual      0    9
# 300       Manual      0   10
#
# [301 rows x 9 columns]

# %%
df.drop(columns="Car_Name",inplace=True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  age
# 0         Manual      0   12
# 1         Manual      0   13
# 2         Manual      0    9
# 3         Manual      0   15
# 4         Manual      0   12
# ..           ...    ...  ...
# 296       Manual      0   10
# 297       Manual      0   11
# 298       Manual      0   17
# 299       Manual      0    9
# 300       Manual      0   10
#
# [301 rows x 8 columns]

# %%
df=pd.get_dummies(data=df,drop_first=True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   12             False
# 1             4.75           9.54       43000      0   13              True
# 2             7.25           9.85        6900      0    9             False
# 3             2.85           4.15        5200      0   15             False
# 4             4.60           6.87       42450      0   12              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0   10              True
# 297           4.00           5.90       60000      0   11             False
# 298           3.35          11.00       87934      0   17             False
# 299          11.50          12.50        9000      0    9              True
# 300           5.30           5.90        5464      0   10             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                True                   False                 True
# 1               False                   False                 True
# 2                True                   False                 True
# 3                True                   False                 True
# 4               False                   False                 True
# ..                ...                     ...                  ...
# 296             False                   False                 True
# 297              True                   False                 True
# 298              True                   False                 True
# 299             False                   False                 True
# 300              True                   False                 True
#
# [301 rows x 9 columns]

# %%
y=df["Selling_Price"]
x=df[['Present_Price', 'Kms_Driven', 'Owner', 'age',
       'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
       'Transmission_Manual']]

# %%
df.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'age',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
# split data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (240, 8)

# %%
x_test.shape
# Out:
# (61, 8)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (61,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# model created
# train - for model creation 
# test= for check accuracy
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# here y is dependent on 8 parameter so 8 output
# Out:
# array([ 4.28802981e-01, -5.92316903e-06, -8.49009727e-01, -4.06411225e-01,
#         2.86056285e+00,  7.03103550e-01, -1.07477347e+00, -1.50897975e+00])

# %%
c=lr.intercept_
c
# Out:
# np.float64(7.257168546907976)

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000      0   12             False              True
# 1           9.54       43000      0   13              True             False
# 2           9.85        6900      0    9             False              True
# 3           4.15        5200      0   15             False              True
# 4           6.87       42450      0   12              True             False
#
#    Seller_Type_Individual  Transmission_Manual
# 0                   False                 True
# 1                   False                 True
# 2                   False                 True
# 3                   False                 True
# 4                   False                 True

# %%
# car is 8 year old ,petrol engine ,manual, 45000km runed ,owner=0 ,present price=8.5 lac,seller type=individual so predict selling price 
i20_price=lr.predict([[8.5,45000,0,8,0,1,1,1]])
# here entered data is by sequence of x from df
i20_price
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.50351181])

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([10.57889241,  0.71754255,  4.23613904,  5.17855444,  9.75533583,
#         4.20615652,  2.6748089 ,  7.63221623,  0.17032381,  5.13283747,
#         6.15727726,  6.44545506,  2.11900126,  7.6644102 ,  1.91710055,
#         1.71680788,  2.02672159,  1.85294787,  9.56717323,  4.23076317,
#         1.48724915,  9.36189904,  1.46103587,  9.54572517,  0.82954545,
#         8.32266051,  1.53698563, -3.16293717,  4.2127377 ,  2.10385587,
#         3.42279444,  3.71284702,  5.54538889,  7.6834828 , -1.89757368,
#         7.06591847,  8.46027656,  5.77704136,  6.10531922,  6.52919752,
#        16.08564344,  2.07410694,  1.05462465, -0.44710144,  7.06940454,
#         6.73548589,  0.98609923,  7.08961114, 14.16420523,  3.00434598,
#         8.2871215 , -0.87862345,  8.8814273 ,  1.15099681,  2.11848057,
#        -0.82641923,  0.69287067,  9.88583992, -0.45444272, -2.41051663,
#        10.28627971])

# %%
from sklearn.metrics import mean_squared_error
print('MSE=',mean_squared_error(y_test,y_predict))
# Out:
# MSE= 2.7506892621397547

# %% [markdown]
# # 228
# Write a program to create a Model using linear regression to predict the wine quality using the csv file provided named
# “winequality.csv”. Do the required process in the data before making a model.
# If you find any null value in “winequality.csv” then replace null value with mean value of respected columns.
# Find co-efficient, intercept and mean squared error.
# also Predict the quality of red wine for the following data:
# fixed acidity: 8
# vola le acidity: 0.4
# citric acid: 0.40
# residual sugar: 15
# chlorides: 0.048
# free sulfur dioxide: 40
# total sulfur dioxide: 150
# density: 0.99
# pH: 3
# sulphates: 0.45
# alcohol: 10.5

# %%
import pandas as pd
df=pd.read_csv('winequality.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.drop(columns="Id",inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
y=df["quality"]
x=df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# Out:
# array([ 3.78284546e-02, -1.11759188e+00, -2.77130273e-01, -1.28697411e-02,
#        -1.68767302e+00,  5.47806497e-03, -3.61202144e-03, -4.42463238e+00,
#        -3.59530151e-01,  7.99871109e-01,  2.85994273e-01])

# %%
c=lr.intercept_
c
# Out:
# np.float64(8.34997746188915)

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([6.09716915, 5.91139964, 5.94226384, 5.35382259, 6.10057125,
#        5.45849875, 5.71013252, 5.06261618, 6.45825661, 5.21191144,
#        5.0515494 , 5.25899919, 4.64146034, 6.14924912, 5.71898361,
#        5.18152094, 5.5188606 , 5.98556   , 5.49819117, 6.14607399,
#        6.11404856, 5.58916965, 6.05863236, 4.98492263, 5.45265824,
#        5.55337972, 5.24160528, 5.81998877, 5.12058643, 4.83791389,
#        6.16690548, 5.08332319, 5.41004078, 5.77254432, 4.83636739,
#        5.17750267, 5.68595523, 5.21165017, 5.35436378, 5.82009348,
#        5.9927855 , 5.33417552, 5.4471274 , 4.98157052, 5.11089707,
#        6.40066265, 5.06047867, 5.41549934, 6.64165936, 5.4848665 ,
#        5.78341692, 5.02019298, 5.59965427, 5.87274109, 5.84718257,
#        5.81309147, 5.25854885, 5.12674202, 5.49234907, 5.61779029,
#        6.18036825, 5.27223745, 6.04599557, 5.60758494, 5.17233237,
#        5.41893383, 6.09680412, 5.72413781, 5.82469382, 5.43443137,
#        5.85398355, 5.26515993, 6.27543143, 5.70769985, 6.08663428,
#        5.38215657, 5.61833659, 6.471853  , 5.89404678, 6.32824476,
#        5.31398573, 5.33482274, 5.81193393, 5.47926787, 4.82380449,
#        5.09399432, 5.67413487, 5.49758997, 5.28604214, 5.35785267,
#        4.9929836 , 6.58318066, 5.98556   , 5.34961475, 5.01776295,
#        6.16934677, 5.48594129, 6.47062324, 4.95691899, 5.51064257,
#        4.85156195, 6.09211055, 6.1800205 , 5.39720212, 6.41723327,
#        4.84600771, 6.12960055, 5.16015651, 5.83185089, 5.11280545,
#        5.67481293, 5.19204591, 5.45337398, 5.28447004, 6.02834615,
#        6.04387165, 6.25279761, 5.52321382, 5.46474518, 6.12131244,
#        5.29095662, 6.32571948, 5.54455701, 5.53052677, 6.11504325,
#        5.59239472, 5.63217638, 5.91168145, 6.07923891, 5.55396146,
#        5.48005576, 6.28285829, 6.32571948, 5.37011154, 5.35902581,
#        5.50001099, 5.77469426, 6.55423274, 5.45680049, 5.29521665,
#        6.58380622, 6.34335958, 5.17863024, 5.34843313, 6.11257102,
#        5.45889104, 5.70859612, 6.2615434 , 5.53818813, 5.19427437,
#        5.091753  , 4.87077573, 6.71626659, 6.17758127, 5.96321672,
#        5.70497184, 5.47103943, 6.67016652, 5.06116274, 4.79553462,
#        5.38215657, 5.39684836, 4.81680093, 5.75875955, 5.62907741,
#        4.85314699, 5.82469382, 5.12359951, 5.12890748, 5.00841245,
#        6.39021408, 6.51809813, 6.1808744 , 6.12293474, 6.36117145,
#        6.08804987, 5.53052677, 5.65101575, 5.0843373 , 6.53494379,
#        5.1513828 , 5.14035865, 5.67643387, 5.38215657, 5.81173159,
#        5.583531  , 5.11719256, 6.11833629, 5.08160782, 5.03416943,
#        5.3525052 , 5.47046791, 5.2448155 , 6.07546519, 5.31432364,
#        5.94186429, 5.92621108, 5.2211008 , 6.23755848, 6.03400609,
#        5.58058944, 4.89749974, 5.3806676 , 5.75593945, 5.4972648 ,
#        6.46701328, 6.24290037, 6.36644193, 5.86312582, 5.22992416,
#        5.91431098, 5.45889104, 5.43266971, 5.73315237, 5.68473057,
#        5.96971066, 5.72724041, 5.03460772, 6.10814772, 5.85964516,
#        5.89026639, 5.1848569 , 5.43347349, 5.50163866, 5.10190638,
#        5.59260733, 4.83464163, 4.95002615, 5.0152206 ])

# %%
from sklearn.metrics import mean_squared_error
print('MSE=',mean_squared_error(y_test,y_predict))
# Out:
# MSE= 0.41806955347492575

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
# prediction of quality of wine
wine=lr.predict([[8,0.4,0.40,15,0.048,40,150,0.99,3,0.45,10.5]])
wine
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.40188655])

# %% [markdown]
# <!--226  -->
# For the given RealEstate csv, write a python program satisfying following tasks to demonstrate application of machine learning
# through multiple linear regression as follows –
# Given: -
# Dataset
# RealEstate.csv
# ML Library to be used    scikit-learn
# Dependent variable
# 'Y house price of unit area'
# Independent variables     'X1 transaction date', 'X2 house age',  'X3 distance to the nearest MRT station', 'X4 number of
# convenience stores', 'X5 latitude' and  'X6 longitude'
# 1. Import required libraries.
# 2. Load RealEstate dataset, create a dataframe and check datatypes of its attributes using appropriate method.
# 3. Remove ‘No’ column from the dataframe.
# 4. Check for any null values in features using appropriate method.
# 5. Create feature variables x and y as given above.
# 6. Create training and testing sets of feature variables with 70% of data for training and with random state of 110.
# 7. Create and fit regression model using appropriate method.
# 8. Use testing set created in step 6 to find and print the prediction of the outcome.
# 9. Find and print coefficient and mean squared error of the regression model.

# %%
import pandas as pd
df=pd.read_csv('RealEstate.csv')
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df.drop("No",inplace=True,axis=1)
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
df.isna().sum()
# Out:
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
y=df['Y house price of unit area']
x=df[['X1 transaction date', 'X2 house age',
       'X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=110)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# Out:
# array([ 6.84308941e+00, -2.25466590e-01, -5.18046265e-03,  1.12369103e+00,
#         1.87739728e+02, -4.29300312e+01])

# %%
c=lr.intercept_
c
# Out:
# np.float64(-13203.674300629997)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([40.06913335, 32.56470479, 29.80668902, 44.60809493, 39.96541473,
#        44.34984726, 37.64834639, 51.18801909, 37.08044432, 38.64449437,
#        36.45757424, 31.64776451, 43.03392987, 16.64984039, 36.61381207,
#        31.21699197, 39.55333345, 41.89770923, 46.41953538, 42.69067202,
#        40.49560609, 53.3447345 , 40.74436408, 36.67049204, 46.86499408,
#        42.78349352, 47.25115307, 40.53653503, 42.57499139, 50.88772177,
#        44.81813044, 41.05114011, 35.39386877, 42.95199941, 13.97578058,
#        30.00463214,  0.32863779, 39.56884707, 47.9626967 , 34.0147913 ,
#        40.23322474, 49.74492584, 36.73990519, 35.39784888, 29.6071314 ,
#        45.83432319, 42.44745248, 37.88237609, 31.55675944, 47.517238  ,
#        35.03089266, 45.17666152, 45.98711652, 47.32685806, 54.18178829,
#        15.18888047, 43.78264851, 44.75385635, 37.69057227, 39.34215811,
#        44.21812376, 44.27270068, 47.84570949, 38.42626454, 41.0626191 ,
#        19.64522484, 47.9626967 , 43.85961508, 37.99756745, 43.80152052,
#        42.39390912, 42.57768877, 44.73329588, 32.31758114, 46.89135756,
#        38.92015239, 40.90438603, 43.95669962, 34.28075691, 25.5851042 ,
#        16.26403643, 45.66098257, 42.05300968, 10.81561309, 31.65043887,
#        49.10789869, 47.40016786, 13.5604683 , 46.02203009, 44.82145569,
#        34.76747867, 35.40469328, 31.48202917, 45.59192922, 42.0246353 ,
#        42.54274755, 14.70678074, 43.68554348, 27.69149444, 43.0460661 ,
#        27.63908623, 35.23545719, 45.89665228, 50.31290226, 42.86214486,
#        44.61671482, 49.59887911, 32.11577476, 31.86965512, 38.39003281,
#        44.58865137, 25.50284004, 46.20113858, 37.45131001, 14.70678074,
#        44.2357441 ,  9.25548578, 37.23816575, 38.97851394, 47.40016786,
#        39.50115693, 32.15412829, 46.99435489, 47.07907957, 53.12308545])

# %%
from sklearn.metrics import mean_squared_error
print('MSE=',mean_squared_error(y_test,y_pred))
# Out:
# MSE= 77.14802598253598

# %%
from sklearn.metrics import mean_absolute_error
print('Ab=',mean_absolute_error(y_test,y_pred))
# Out:
# Ab= 6.443245493782295

# %%
from sklearn.metrics import r2_score
print('R2=',r2_score(y_test,y_pred))
# here model is 54 percent accurate
# Out:
# R2= 0.5447865064578825

# %% [markdown]
# <!-- 222 -->
# Write a program to create a Model using linear regression to predict the price of house using the csv file provided named
# “Housing.csv”. Do the required process in the data before making a model. Find predicted values, co-efficients, intercept and
# mean squared error.
# https://github.com/pdsinroza/python2/blob/39b36bf2f0121910fd1207952aa0ec20b2d77cfb/housing.csv

# %%
import pandas as pd
df=pd.read_csv('housing.csv')
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
# Polynomial Regression

# %%
import pandas as pd
df=pd.read_csv('Ice_cream selling data.csv')
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df['Temperature (°C)'],df['Ice Cream Sales (units)'])
plt.show()

# %%
y=df['Ice Cream Sales (units)']
x=df[['Temperature (°C)']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_train.head(1)
# Out:
#     Temperature (°C)
# 12          -2.11187

# %%
x_train_poly=poly.fit_transform(x_train)
x_train_poly
# transformin x_train data into polynomial for degrees
# Out:
# array([[ 1.00000000e+00, -2.11186969e+00,  4.45999359e+00,
#         -9.41892528e+00],
#        [ 1.00000000e+00, -3.57855372e+00,  1.28060467e+01,
#         -4.58271260e+01],
#        [ 1.00000000e+00,  2.31859124e+00,  5.37586534e+00,
#          1.24644343e+01],
#        [ 1.00000000e+00, -2.67246083e+00,  7.14204687e+00,
#         -1.90868405e+01],
#        [ 1.00000000e+00, -3.94966109e+00,  1.55998227e+01,
#         -6.16140128e+01],
#        [ 1.00000000e+00, -3.10844012e+00,  9.66239999e+00,
#         -3.00349918e+01],
#        [ 1.00000000e+00,  3.21136614e+00,  1.03128725e+01,
#          3.31184096e+01],
#        [ 1.00000000e+00,  3.27004407e+00,  1.06931882e+01,
#          3.49671967e+01],
#        [ 1.00000000e+00,  4.13086796e+00,  1.70640701e+01,
#          7.04894205e+01],
#        [ 1.00000000e+00, -1.32637898e+00,  1.75928121e+00,
#         -2.33347362e+00],
#        [ 1.00000000e+00, -2.65228679e+00,  7.03462523e+00,
#         -1.86578436e+01],
#        [ 1.00000000e+00, -1.17312327e+00,  1.37621820e+00,
#         -1.61447359e+00],
#        [ 1.00000000e+00,  6.88780908e-01,  4.74419139e-01,
#          3.26770845e-01],
#        [ 1.00000000e+00,  2.07510060e+00,  4.30604249e+00,
#          8.93547133e+00],
#        [ 1.00000000e+00,  1.74000001e+00,  3.02760004e+00,
#          5.26802411e+00],
#        [ 1.00000000e+00, -4.66226268e+00,  2.17366933e+01,
#         -1.01342174e+02],
#        [ 1.00000000e+00,  3.33593241e+00,  1.11284451e+01,
#          3.71237406e+01],
#        [ 1.00000000e+00,  1.99931037e+00,  3.99724195e+00,
#          7.99172728e+00],
#        [ 1.00000000e+00, -3.45571170e+00,  1.19419433e+01,
#         -4.12679133e+01],
#        [ 1.00000000e+00,  1.35981267e+00,  1.84909051e+00,
#          2.51441671e+00],
#        [ 1.00000000e+00, -2.28826400e+00,  5.23615213e+00,
#         -1.19816984e+01],
#        [ 1.00000000e+00,  2.78483646e+00,  7.75531413e+00,
#          2.15972816e+01],
#        [ 1.00000000e+00, -4.31655945e+00,  1.86326855e+01,
#         -8.04290944e+01],
#        [ 1.00000000e+00, -3.38952856e-02,  1.14889038e-03,
#         -3.89419677e-05],
#        [ 1.00000000e+00, -4.21398476e+00,  1.77576676e+01,
#         -7.48305407e+01],
#        [ 1.00000000e+00,  2.83176021e+00,  8.01886589e+00,
#          2.27075054e+01],
#        [ 1.00000000e+00,  2.47194600e+00,  6.11051701e+00,
#          1.51048681e+01],
#        [ 1.00000000e+00,  1.49244574e-01,  2.22739429e-02,
#          3.32426512e-03],
#        [ 1.00000000e+00,  3.02087431e+00,  9.12568162e+00,
#          2.75675372e+01],
#        [ 1.00000000e+00, -2.65149803e+00,  7.03044182e+00,
#         -1.86412027e+01],
#        [ 1.00000000e+00,  8.60769873e-03,  7.40924775e-05,
#          6.37765724e-07],
#        [ 1.00000000e+00, -6.73752802e-01,  4.53942838e-01,
#         -3.05845259e-01],
#        [ 1.00000000e+00,  4.89903151e+00,  2.40005098e+01,
#          1.17579254e+02],
#        [ 1.00000000e+00, -3.61564977e-02,  1.30729232e-03,
#         -4.72671119e-05],
#        [ 1.00000000e+00, -3.08130332e+00,  9.49443018e+00,
#         -2.92552193e+01],
#        [ 1.00000000e+00,  3.31607252e+00,  1.09963370e+01,
#          3.64646508e+01],
#        [ 1.00000000e+00, -1.66034773e+00,  2.75675458e+00,
#         -4.57717121e+00],
#        [ 1.00000000e+00,  1.24071162e+00,  1.53936532e+00,
#          1.90990844e+00],
#        [ 1.00000000e+00,  2.95993209e+00,  8.76119799e+00,
#          2.59325511e+01]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# Out:
# array([ 0.        , -1.39956426,  1.87501919,  0.05451597])

# %%
c=lr.intercept_
c
# Out:
# np.float64(2.840530985282797)

# %%
y1=poly.transform([[10]])
y1
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[   1.,   10.,  100., 1000.]])

# %%
p1=lr.predict(y1)
p1
# Out:
# array([230.86277446])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
x_test_poly=poly.transform(x_test)
# transform x_test into x_test_poly

# %%
y_pred=lr.predict(x_test_poly)

# %%
print("MSE = ",mean_squared_error(y_test,y_pred))
print("MAE = ",mean_absolute_error(y_test,y_pred))
print("R2 = ",r2_score(y_test,y_pred))
# Out:
# MSE =  15.120009451229496
# MAE =  3.22812112977689
# R2 =  0.8405107685716914
